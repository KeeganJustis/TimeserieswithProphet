# %%
#Main imports 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import quandl
import pyflux as pf

# %%
# Grabs the Zillow Seattle Median Price per square foot of houses sold in USA  Quandl

# %%
seattledata= quandl.get("ZILLOW/Z98136_MSPFAH")

# %%
seattledata.head()
# Out:
#                Value
# Date
# 1996-04-30  101.9273
# 1996-05-31  100.1644
# 1996-06-30  101.9912
# 1996-07-31   98.5087
# 1996-08-31   99.9461

# %%
seattledata=seattledata.reset_index()

# %%
seattledata.tail()
# Out:
#           Date  Value
# 250 2017-02-28  411.0
# 251 2017-03-31  416.0
# 252 2017-04-30  425.0
# 253 2017-05-31  434.0
# 254 2017-06-30  441.0

# %%
seattledata.count()
# Out:
# Date     255
# Value    255
# dtype: int64

# %%
#Plotting the data
plt.figure(figsize=(20,9))
plt.plot_date(seattledata['Date'], y=seattledata['Value'],xdate=True)

# %%
timeseries = seattledata['Value']

# %%
timeseries.rolling(12).mean().plot(label='12 Month Rolling Mean')
timeseries.rolling(12).std().plot(label='12 Month Rolling Std')
timeseries.plot()
plt.legend()

# %%
seattledata = seattledata.rename(columns={'Date': 'ds',
                        'Value': 'y'})

seattledata.head(5)
# Out:
#           ds         y
# 0 1996-04-30  101.9273
# 1 1996-05-31  100.1644
# 2 1996-06-30  101.9912
# 3 1996-07-31   98.5087
# 4 1996-08-31   99.9461

# %%
from fbprophet import Prophet

# %%
my_model = Prophet(interval_width=0.95)

# %%
my_model.fit(seattledata)
# Out:
# INFO:fbprophet.forecaster:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet.forecaster:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
future_dates = my_model.make_future_dataframe(periods=36, freq='MS')
future_dates.tail()
# Out:
#             ds
# 286 2020-02-01
# 287 2020-03-01
# 288 2020-04-01
# 289 2020-05-01
# 290 2020-06-01

# %%
forecast = my_model.predict(future_dates)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#             ds        yhat  yhat_lower  yhat_upper
# 286 2020-02-01  494.192618  448.097852  537.487900
# 287 2020-03-01  518.335535  473.446925  561.697823
# 288 2020-04-01  523.410090  473.657760  569.421915
# 289 2020-05-01  522.798599  472.451326  568.218206
# 290 2020-06-01  506.183678  449.231289  554.322794

# %%
my_model.plot(forecast,
              uncertainty=True)

# %%
my_model.plot_components(forecast)

# %%
forecast.tail()
# Out:
#             ds       trend  yhat_lower  yhat_upper  trend_lower  trend_upper  \
# 286 2020-02-01  507.479137  448.097852  537.487900   475.570255   535.574289
# 287 2020-03-01  510.356574  473.446925  561.697823   477.430742   539.684653
# 288 2020-04-01  513.432455  473.657760  569.421915   479.434873   544.220239
# 289 2020-05-01  516.409114  472.451326  568.218206   481.795465   548.712143
# 290 2020-06-01  519.484995  449.231289  554.322794   483.344246   553.120604
#
#       seasonal  seasonal_lower  seasonal_upper  seasonalities  \
# 286 -13.286519      -13.286519      -13.286519     -13.286519
# 287   7.978961        7.978961        7.978961       7.978961
# 288   9.977635        9.977635        9.977635       9.977635
# 289   6.389485        6.389485        6.389485       6.389485
# 290 -13.301317      -13.301317      -13.301317     -13.301317
#
#      seasonalities_lower  seasonalities_upper     yearly  yearly_lower  \
# 286           -13.286519           -13.286519 -13.286519    -13.286519
# 287             7.978961             7.978961   7.978961      7.978961
# 288             9.977635             9.977635   9.977635      9.977635
# 289             6.389485             6.389485   6.389485      6.389485
# 290           -13.301317           -13.301317 -13.301317    -13.301317
#
#      yearly_upper        yhat
# 286    -13.286519  494.192618
# 287      7.978961  518.335535
# 288      9.977635  523.410090
# 289      6.389485  522.798599
# 290    -13.301317  506.183678
